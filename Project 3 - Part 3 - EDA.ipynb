# %% [markdown]
# # Project 3 - Part 3 - EDA
# Author:Paul Foy

# %% [markdown]
# ## Imports and Load Data

# %%
#Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json

# %%
#Load data from 2000 file
df_2000 = pd.read_csv('Data/final_tmdb_data_2000.csv.gz')
df_2000.head()
# Out:
#    Unnamed: 0    imdb_id  adult                     backdrop_path  \
# 0           0          0    NaN                               NaN
# 1           1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2           2  tt0113092    0.0                               NaN
# 3           3  tt0116391    0.0                               NaN
# 4           4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
#
#   belongs_to_collection      budget  \
# 0                   NaN         NaN
# 1                   NaN  10000000.0
# 2                   NaN         0.0
# 3                   NaN         0.0
# 4                   NaN    150000.0
#
#                                               genres homepage        id  \
# 0                                                NaN      NaN       NaN
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN   62127.0
# 2           [{'id': 878, 'name': 'Science Fiction'}]      NaN  110977.0
# ...

# %%
#Load data from 2001 file
df_2001 = pd.read_csv('Data/final_tmdb_data_2001.csv.gz')
df_2001.head()
# Out:
#    Unnamed: 0    imdb_id  adult                     backdrop_path  \
# 0           0          0    NaN                               NaN
# 1           1  tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg
# 2           2  tt0114447    0.0                               NaN
# 3           3  tt0116916    0.0  /rFpHBidSlhjflmnLu7BZilyKeQR.jpg
# 4           4  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg
#
#   belongs_to_collection      budget  \
# 0                   NaN         NaN
# 1                   NaN  48000000.0
# 2                   NaN         0.0
# 3                   NaN         0.0
# 4                   NaN  22000000.0
#
#                                               genres homepage        id  \
# 0                                                NaN      NaN       NaN
# 1  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN   11232.0
# 2  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN  151007.0
# ...

# %% [markdown]
# ## Combine both datasets into single dataframe and CSV file

# %%
#Concatenate into one dataframe
df1 = pd.concat((df_2000, df_2001))
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3046 entries, 0 to 1557
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             3046 non-null   int64
#  1   imdb_id                3046 non-null   object
#  2   adult                  3044 non-null   float64
#  3   backdrop_path          1654 non-null   object
#  4   belongs_to_collection  241 non-null    object
#  5   budget                 3044 non-null   float64
#  6   genres                 3044 non-null   object
#  7   homepage               184 non-null    object
#  8   id                     3044 non-null   float64
#  9   original_language      3044 non-null   object
#  10  original_title         3044 non-null   object
#  11  overview               2989 non-null   object
#  12  popularity             3044 non-null   float64
#  13  poster_path            2760 non-null   object
# ...

# %%
FOLDER = "Data/"
df1.to_csv(f"{FOLDER}tmdb_results_combined.csv.gz")

# %% [markdown]
# ## EDA

# %% [markdown]
# ### 1. How many movies had at least some valid financial information (values > 0 for budget OR revenue)?

# %%
budget_df = df1[(df1['budget'] > 0) | (df1['revenue'] > 0)]
print(f'The number of movies with budget or revenue greater than 0 is {len(budget_df)}.')
# Out:
# The number of movies with budget or revenue greater than 0 is 658.

# %% [markdown]
# **Note: Please exclude any movies with 0's for budget AND revenue from the remaining visualizations.**

# %% [markdown]
# ### 2. How many movies are there in each of the certification categories (G/PG/PG-13/R)?

# %%
sns.countplot(data=budget_df, x='certification')
# Set the title and axis labels
plt.title('Movies by Certification Category')
plt.xlabel('Certification type')
plt.ylabel('Number of Movies')

# Show the plot
plt.show()

# %% [markdown]
# ### 3. What is the average revenue per certification category?

# %%
sns.barplot(data=budget_df, x='certification', y='revenue');

# Set the title and axis labels
plt.title('Average Revenue per Certification Type')
plt.xlabel('Certification Type')
plt.ylabel('Average Revenue')
# Out:
# Text(0, 0.5, 'Average Revenue')

# %% [markdown]
# ### 4. What is the average budget per certification category?

# %%
sns.barplot(data=budget_df, x='certification', y='budget');

# Set the title and axis labels
plt.title('Average Budget per Certification Type')
plt.xlabel('Certification Type')
plt.ylabel('Average Budget')
# Out:
# Text(0, 0.5, 'Average Budget')
