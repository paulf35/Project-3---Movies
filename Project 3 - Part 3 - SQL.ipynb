# %% [markdown]
# # Project 3 -  Part 3 -  SQL (Core)

# %% [markdown]
# ## Imports and Auth

# %%
# Imports
import pandas as pd
import numpy as np


from sqlalchemy import create_engine
from sqlalchemy_utils import database_exists, create_database
import pymysql
pymysql.install_as_MySQLdb()
from urllib.parse import quote_plus as urlquote

# %%
# Install tmdbsimple (only need to run once)
# !pip install tmdbsimple

# %%
import json
with open('/Users/pafoy_gz6qkdd/.secret/mysql.json', 'r') as f:
    login = json.load(f)
## Display the keys of the loaded dict
login.keys()
# Out:
# dict_keys(['username', 'password'])

# %% [markdown]
# ## Connect to MySQL

# %%
#Create MySQL connection string
connection = f"mysql+pymysql://{login['username']}:{urlquote(login['password'])}@localhost/movies"
engine = create_engine(connection)

# %%
#Check if database exists, if not, create it
if database_exists(connection):
    print('It exists!')
else:
    create_database(connection)
    print('Database created!')
# Out:
# Database created!

# %% [markdown]
# ## Load and update data

# %%
#TMDB_2000 movies
df_2000 = pd.read_csv('Data/final_tmdb_data_2000.csv.gz')
df_2000.head()
# Out:
#    Unnamed: 0    imdb_id  adult                     backdrop_path  \
# 0           0          0    NaN                               NaN
# 1           1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg
# 2           2  tt0113092    0.0                               NaN
# 3           3  tt0116391    0.0                               NaN
# 4           4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg
#
#   belongs_to_collection      budget  \
# 0                   NaN         NaN
# 1                   NaN  10000000.0
# 2                   NaN         0.0
# 3                   NaN         0.0
# 4                   NaN    150000.0
#
#                                               genres homepage        id  \
# 0                                                NaN      NaN       NaN
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...      NaN   62127.0
# 2           [{'id': 878, 'name': 'Science Fiction'}]      NaN  110977.0
# ...

# %%
#TMDB_2001 movies
df_2001 = pd.read_csv('Data/final_tmdb_data_2001.csv.gz')
df_2001.head()
# Out:
#    Unnamed: 0    imdb_id  adult                     backdrop_path  \
# 0           0          0    NaN                               NaN
# 1           1  tt0035423    0.0  /hfeiSfWYujh6MKhtGTXyK3DD4nN.jpg
# 2           2  tt0114447    0.0                               NaN
# 3           3  tt0116916    0.0  /rFpHBidSlhjflmnLu7BZilyKeQR.jpg
# 4           4  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg
#
#   belongs_to_collection      budget  \
# 0                   NaN         NaN
# 1                   NaN  48000000.0
# 2                   NaN         0.0
# 3                   NaN         0.0
# 4                   NaN  22000000.0
#
#                                               genres homepage        id  \
# 0                                                NaN      NaN       NaN
# 1  [{'id': 10749, 'name': 'Romance'}, {'id': 14, ...      NaN   11232.0
# 2  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN  151007.0
# ...

# %%
#Title_ratings
title_ratings = pd.read_csv('Data/title_ratings.csv.gz')
title_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1990
# 1  tt0000002            5.8       264
# 2  tt0000005            6.2      2647
# 3  tt0000006            5.0       182
# 4  tt0000007            5.4       829

# %%
#Title_basics
title_basics = pd.read_csv('Data/title_basics.csv.gz')
title_basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0068865     movie                                Lives of Performers
# 3  tt0069049     movie                         The Other Side of the Wind
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                        Lives of Performers        0     2016.0      NaN
# 3                 The Other Side of the Wind        0     2018.0      NaN
# 4                          The Naked Monster        0     2005.0      NaN
#
#    runtimeMinutes                  genres
# ...

# %%
#Concatenate TMDB files into one dataframe
tmdb_data = pd.concat((df_2000, df_2001))
tmdb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3046 entries, 0 to 1557
# Data columns (total 27 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             3046 non-null   int64
#  1   imdb_id                3046 non-null   object
#  2   adult                  3044 non-null   float64
#  3   backdrop_path          1654 non-null   object
#  4   belongs_to_collection  241 non-null    object
#  5   budget                 3044 non-null   float64
#  6   genres                 3044 non-null   object
#  7   homepage               184 non-null    object
#  8   id                     3044 non-null   float64
#  9   original_language      3044 non-null   object
#  10  original_title         3044 non-null   object
#  11  overview               2989 non-null   object
#  12  popularity             3044 non-null   float64
#  13  poster_path            2760 non-null   object
# ...

# %% [markdown]
# ## SQL Table Normalization

# %%
#Drop unneeded columns from tmbd_data
tmdb_data= tmdb_data.drop(columns = ['Unnamed: 0','adult', 'backdrop_path', 
                                      'belongs_to_collection', 'genres', 
                                      'homepage', 'id', 'original_language', 
                                      'original_title', 'overview', 'popularity', 
                                      'poster_path', 'production_companies', 
                                      'production_countries', 'release_date', 
                                      'runtime', 'spoken_languages', 'status', 
                                      'tagline', 'title', 'video', 'vote_average', 
                                      'vote_count'])
#Verify the drop
tmdb_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3046 entries, 0 to 1557
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   imdb_id        3046 non-null   object
#  1   budget         3044 non-null   float64
#  2   revenue        3044 non-null   float64
#  3   certification  939 non-null    object
# dtypes: float64(2), object(2)
# memory usage: 119.0+ KB

# %% [markdown]
# ## Update basics data

# %%
#Create new column in basics with list of genres
title_basics['genres_split'] = title_basics['genres'].str.split(',')
title_basics
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0068865     movie                                Lives of Performers
# 3      tt0069049     movie                         The Other Side of the Wind
# 4      tt0088751     movie                                  The Naked Monster
# ...          ...       ...                                                ...
# 90799  tt9914942     movie                             Life Without Sara Amat
# 90800  tt9915872     movie                               The Last White Witch
# 90801  tt9916170     movie                                      The Rehearsal
# 90802  tt9916190     movie                                          Safeguard
# 90803  tt9916362     movie                                              Coven
#
# ...

# %%
#Separate genres into new rows
exploded_genres = title_basics.explode('genres_split')
exploded_genres
# Out:
#           tconst titleType                                       primaryTitle  \
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 0      tt0035423     movie                                     Kate & Leopold
# 1      tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2      tt0068865     movie                                Lives of Performers
# ...          ...       ...                                                ...
# 90802  tt9916190     movie                                          Safeguard
# 90802  tt9916190     movie                                          Safeguard
# 90802  tt9916190     movie                                          Safeguard
# 90803  tt9916362     movie                                              Coven
# 90803  tt9916362     movie                                              Coven
#
# ...

# %%
#Sort genres alphabetically
unique_genres = sorted(exploded_genres['genres_split'].unique())

#Create title_genres
title_genres = exploded_genres[['tconst', 'genres_split']].copy()
title_genres.head()
# Out:
#       tconst genres_split
# 0  tt0035423       Comedy
# 0  tt0035423      Fantasy
# 0  tt0035423      Romance
# 1  tt0062336        Drama
# 2  tt0068865        Drama

# %%
#Create genre mapper dictionary
genre_ints = range(len(unique_genres))
genre_map = dict(zip(unique_genres, genre_ints))
genre_map
# Out:
# {'Action': 0,
#  'Adult': 1,
#  'Adventure': 2,
#  'Animation': 3,
#  'Biography': 4,
#  'Comedy': 5,
#  'Crime': 6,
#  'Drama': 7,
#  'Family': 8,
#  'Fantasy': 9,
#  'Game-Show': 10,
#  'History': 11,
#  'Horror': 12,
#  'Music': 13,
#  'Musical': 14,
#  'Mystery': 15,
#  'News': 16,
#  'Reality-TV': 17,
#  'Romance': 18,
#  'Sci-Fi': 19,
#  'Sport': 20,
#  'Talk-Show': 21,
#  'Thriller': 22,
#  'War': 23,
#  'Western': 24}

# %%
#Make new  column in title_genres table
title_genres['genre_id'] = title_genres['genres_split'].map(genre_map)
title_genres = title_genres.drop(columns = 'genres_split')
title_genres.head()
# Out:
#       tconst  genre_id
# 0  tt0035423         5
# 0  tt0035423         9
# 0  tt0035423        18
# 1  tt0062336         7
# 2  tt0068865         7

# %%
#Convert genre map dictionary into genres table
genres = pd.DataFrame({'Genre_Name': genre_map.keys(),
                      'Genre_ID': genre_map.values()})
genres.head()
# Out:
#   Genre_Name  Genre_ID
# 0     Action         0
# 1      Adult         1
# 2  Adventure         2
# 3  Animation         3
# 4  Biography         4

# %%
#Drop columns from title_basics df
title_basics = title_basics.drop(columns = ['titleType', 'originalTitle', 
                                            'isAdult', 'endYear', 'genres', 
                                            'genres_split'])
#Verify the change
title_basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 90804 entries, 0 to 90803
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          90804 non-null  object
#  1   primaryTitle    90804 non-null  object
#  2   startYear       90804 non-null  float64
#  3   runtimeMinutes  90804 non-null  int64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 2.8+ MB

# %% [markdown]
# ## Create tables in 'movies' database

# %% [markdown]
# ### Create title_basics

# %%
#Check data types of df
title_basics.dtypes
# Out:
# tconst             object
# primaryTitle       object
# startYear         float64
# runtimeMinutes      int64
# dtype: object

# %%
from sqlalchemy.types import *

#Calculate max string lengths for object columns
id_len = title_basics['tconst'].fillna('').map(len).max()
title_len = title_basics['primaryTitle'].fillna('').map(len).max()

## Create a schema dictonary using Sqlalchemy datatype objects
title_basics_schema = {
    "tconst": String(id_len+1), 
    "primaryTitle": Text(title_len+1),
    'startYear':Float(),
    'runtimeMinutes':Integer()}

# %%
#Save table to sql
title_basics.to_sql('title_basics', engine, dtype = title_basics_schema, 
                    if_exists = 'replace', index = False)
# Out:
# 90804

# %%
#Add tconst as prim key
engine.execute('ALTER TABLE title_basics ADD PRIMARY KEY (`tconst`);')

# %%
#Show first 5 rows of basics
q = """
SELECT *
FROM title_basics
LIMIT 5;
"""
pd.read_sql(q, engine)
# Out:
#       tconst                                       primaryTitle  startYear  \
# 0  tt0035423                                     Kate & Leopold     2001.0
# 1  tt0062336  The Tango of the Widower and Its Distorting Mi...     2020.0
# 2  tt0068865                                Lives of Performers     2016.0
# 3  tt0069049                         The Other Side of the Wind     2018.0
# 4  tt0088751                                  The Naked Monster     2005.0
#
#    runtimeMinutes
# 0             118
# 1              70
# 2              90
# 3             122
# 4             100

# %% [markdown]
# ### Create title_ratings

# %%
#Check data types of df
title_ratings.dtypes
# Out:
# tconst            object
# averageRating    float64
# numVotes           int64
# dtype: object

# %%
#Calculate max string lengths for object columns
id_len = title_ratings['tconst'].fillna('').map(len).max()

## Create a schema dictonary using Sqlalchemy datatype objects
title_ratings_schema = {
    "tconst": String(id_len+1), 
    'averageRating':Float(),
    'numVotes':Integer()}

# %%
#Save table to sql
title_ratings.to_sql('title_ratings', engine, dtype = title_ratings_schema, 
                    if_exists = 'replace', index = False)
# Out:
# 505073

# %%
#Add tconst as prim key
engine.execute('ALTER TABLE title_ratings ADD PRIMARY KEY (`tconst`);')

# %%
#Query to run first 5 rows of ratings table
q = """
SELECT *
FROM title_ratings
LIMIT 5;
"""
pd.read_sql(q, engine)
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1990
# 1  tt0000002            5.8       264
# 2  tt0000005            6.2      2647
# 3  tt0000006            5.0       182
# 4  tt0000007            5.4       829

# %% [markdown]
# ### Create title_genres

# %%
title_genres.dtypes
# Out:
# tconst      object
# genre_id     int64
# dtype: object

# %%
#Save table to sql
title_genres.to_sql('title_genres', engine, if_exists = 'replace')
# Out:
# 168963

# %%
#Query to run first 5 rows in table
q = """
SELECT *
FROM title_genres
LIMIT 5;
"""
pd.read_sql(q, engine)
# Out:
#    index     tconst  genre_id
# 0      0  tt0035423         5
# 1      0  tt0035423         9
# 2      0  tt0035423        18
# 3      1  tt0062336         7
# 4      2  tt0068865         7

# %% [markdown]
# ### Create genres

# %%
genres.dtypes
# Out:
# Genre_Name    object
# Genre_ID       int64
# dtype: object

# %%
#Save table to sql
genres.set_index('Genre_ID').to_sql('genres', engine, if_exists = 'replace', index=True)
# Out:
# 25

# %%
#Query to run first 5 rows in table
q = """
SELECT *
FROM genres
LIMIT 5;
"""
pd.read_sql(q, engine)
# Out:
#    Genre_ID Genre_Name
# 0         0     Action
# 1         1      Adult
# 2         2  Adventure
# 3         3  Animation
# 4         4  Biography

# %%
### Create tmdb_data

# %%
#Check data types of df
tmdb_data.dtypes
# Out:
# imdb_id           object
# budget           float64
# revenue          float64
# certification     object
# dtype: object

# %%
tmdb_data.head()
# Out:
#      imdb_id      budget     revenue certification
# 0          0         NaN         NaN           NaN
# 1  tt0113026  10000000.0         0.0           NaN
# 2  tt0113092         0.0         0.0           NaN
# 3  tt0116391         0.0         0.0           NaN
# 4  tt0118694    150000.0  14204632.0            PG

# %%
#drop first row of table to avoid dup prim key id
tmdb_data = tmdb_data.drop([0])

# %%
#Calculate max string lengths for object columns
id_len = tmdb_data['imdb_id'].fillna('').map(len).max()
cert_len = tmdb_data['certification'].fillna('').map(len).max()
## Create a schema dictonary using Sqlalchemy datatype objects
tmdb_schema = {
    "imdb_id": String(id_len+1),
    'budget':Float(),
    'revenue':Float(),
    'certification':Text(cert_len+1)}

# %%
#Save table to sql
tmdb_data.to_sql('tmdb_data', engine, dtype = tmdb_schema, 
                    if_exists = 'replace', index = False)
# Out:
# 3044

# %%
#Add imdb_id as primary key
engine.execute('ALTER TABLE tmdb_data ADD PRIMARY KEY (`imdb_id`);')

# %%
#Query to run first 5 rows
q = """
SELECT *
FROM tmdb_data
LIMIT 5;
"""
pd.read_sql(q, engine)
# Out:
#      imdb_id      budget     revenue certification
# 0  tt0035423  48000000.0  76019000.0         PG-13
# 1  tt0113026  10000000.0         0.0          None
# 2  tt0113092         0.0         0.0          None
# 3  tt0114447         0.0         0.0          None
# 4  tt0116391         0.0         0.0          None

# %% [markdown]
# ### Final Query to show all tables in DB

# %%
#Final query
#Show tables in database
q = """SHOW TABLES;"""
pd.read_sql(q, engine)
# Out:
#   Tables_in_movies
# 0           genres
# 1     title_basics
# 2     title_genres
# 3    title_ratings
# 4        tmdb_data
