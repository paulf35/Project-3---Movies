# %%
# imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load data
basics = pd.read_csv('https://datasets.imdbws.com/title.basics.tsv.gz', sep='\t', low_memory=False)
akas = pd.read_csv('https://datasets.imdbws.com/title.akas.tsv.gz', sep='\t', low_memory=False)
ratings = pd.read_csv('https://datasets.imdbws.com/title.ratings.tsv.gz', sep='\t', low_memory=False)

# %% [markdown]
# # Explore Data

# %%
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA       \N
# 1  tt0000001         2                 Carmencita     DE       \N
# 2  tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3  tt0000001         4                 Καρμενσίτα     GR       \N
# 4  tt0000001         5                 Карменсита     RU       \N
#
#          types     attributes isOriginalTitle
# 0  imdbDisplay             \N               0
# 1           \N  literal title               0
# 2  imdbDisplay             \N               0
# 3  imdbDisplay             \N               0
# 4  imdbDisplay             \N               0

# %%
akas['region'].value_counts()
# Out:
# US    1461196
# Name: region, dtype: int64

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1990
# 1  tt0000002            5.8       264
# 2  tt0000003            6.5      1862
# 3  tt0000004            5.5       177
# 4  tt0000005            6.2      2647

# %% [markdown]
# # Data Cleanup

# %% [markdown]
# ## Cleanup AKAs Data Set
#
# - Keep only US movies
# - Replace "\N" with np.nan

# %%
# Remove non-US values
akas.drop(df_akas[df_akas['region'] != 'US'].index, inplace=True)

#Replace "\N" with np.nan
akas.replace({'\\N':np.nan}, inplace=True)
akas
# Out:
#             titleId  ordering                                      title  \
# 5         tt0000001         6                                 Carmencita
# 14        tt0000002         7                     The Clown and His Dogs
# 33        tt0000005        10                           Blacksmith Scene
# 36        tt0000005         1                        Blacksmithing Scene
# 41        tt0000005         6                        Blacksmith Scene #1
# ...             ...       ...                                        ...
# 36939955  tt9916560         1  March of Dimes Presents: Once Upon a Dime
# 36940025  tt9916620         1                          The Copeland Case
# 36940114  tt9916702         1              Loving London: The Playground
# 36940157  tt9916756         1                   Pretty Pretty Black Girl
# 36940173  tt9916764         1                                         38
#
#          region language        types             attributes isOriginalTitle
# 5            US      NaN  imdbDisplay                    NaN               0
# 14           US      NaN          NaN  literal English title               0
# 33           US      NaN  imdbDisplay                    NaN               0
# 36           US      NaN  alternative                    NaN               0
# 41           US      NaN  alternative                    NaN               0
# ...         ...      ...          ...                    ...             ...
# 36939955     US      NaN  imdbDisplay                    NaN               0
# 36940025     US      NaN  imdbDisplay                    NaN               0
# 36940114     US      NaN          NaN                    NaN               0
# 36940157     US      NaN  imdbDisplay                    NaN               0
# 36940173     US      NaN  imdbDisplay                    NaN               0
#
# [1461196 rows x 8 columns]

# %% [markdown]
# ## Cleanup Title Basics Dataset
# - Keep only US movies (Use AKAs table, see "Filtering one dataframe based on another" section below)
# - Replace "\N" with np.nan
# - Eliminate movies that are null for runtimeMinutes
# - Eliminate movies that are null for genre
# - keep only titleType==Movie
# - Convert the startYear column to float data type.
# - Filter the dataframe using startYear. Keep years between 2000-2021 (Including 2000 and 2021)
# - Eliminate movies that include "Documentary" in the genre (see tip below).

# %%
# Keep only US movies
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers = basics['tconst'].isin(df_akas['titleId'])
keepers
basics = basics[keepers]
basics
# Out:
#              tconst titleType                                 primaryTitle  \
# 0         tt0000001     short                                   Carmencita
# 1         tt0000002     short                       Le clown et ses chiens
# 4         tt0000005     short                             Blacksmith Scene
# 5         tt0000006     short                            Chinese Opium Den
# 6         tt0000007     short  Corbett and Courtney Before the Kinetograph
# ...             ...       ...                                          ...
# 10100656  tt9916560   tvMovie    March of Dimes Presents: Once Upon a Dime
# 10100685  tt9916620     movie                            The Copeland Case
# 10100723  tt9916702     short                Loving London: The Playground
# 10100746  tt9916756     short                     Pretty Pretty Black Girl
# 10100750  tt9916764     short                                           38
#
#                                         originalTitle isAdult startYear  \
# 0                                          Carmencita       0      1894
# 1                              Le clown et ses chiens       0      1892
# 4                                    Blacksmith Scene       0      1893
# 5                                   Chinese Opium Den       0      1894
# 6         Corbett and Courtney Before the Kinetograph       0      1894
# ...                                               ...     ...       ...
# 10100656    March of Dimes Presents: Once Upon a Dime       0      1963
# 10100685                            The Copeland Case       0        \N
# 10100723                Loving London: The Playground       0        \N
# 10100746                     Pretty Pretty Black Girl       0      2019
# 10100750                                           38       0      2018
#
#          endYear runtimeMinutes             genres
# 0             \N              1  Documentary,Short
# 1             \N              5    Animation,Short
# 4             \N              1       Comedy,Short
# 5             \N              1              Short
# 6             \N              1        Short,Sport
# ...          ...            ...                ...
# 10100656      \N             58             Family
# 10100685      \N             \N              Drama
# 10100723      \N             \N        Drama,Short
# 10100746      \N             \N              Short
# 10100750      \N             \N              Short
#
# [1373833 rows x 9 columns]

# %%
#Replace "\N" with np.nan
basics.replace({'\\N':np.nan}, inplace=True)
basics
# Out:
#              tconst titleType                                 primaryTitle  \
# 0         tt0000001     short                                   Carmencita
# 1         tt0000002     short                       Le clown et ses chiens
# 4         tt0000005     short                             Blacksmith Scene
# 5         tt0000006     short                            Chinese Opium Den
# 6         tt0000007     short  Corbett and Courtney Before the Kinetograph
# ...             ...       ...                                          ...
# 10100656  tt9916560   tvMovie    March of Dimes Presents: Once Upon a Dime
# 10100685  tt9916620     movie                            The Copeland Case
# 10100723  tt9916702     short                Loving London: The Playground
# 10100746  tt9916756     short                     Pretty Pretty Black Girl
# 10100750  tt9916764     short                                           38
#
#                                         originalTitle isAdult startYear  \
# 0                                          Carmencita       0      1894
# 1                              Le clown et ses chiens       0      1892
# 4                                    Blacksmith Scene       0      1893
# 5                                   Chinese Opium Den       0      1894
# 6         Corbett and Courtney Before the Kinetograph       0      1894
# ...                                               ...     ...       ...
# 10100656    March of Dimes Presents: Once Upon a Dime       0      1963
# 10100685                            The Copeland Case       0       NaN
# 10100723                Loving London: The Playground       0       NaN
# 10100746                     Pretty Pretty Black Girl       0      2019
# 10100750                                           38       0      2018
#
#          endYear runtimeMinutes             genres
# 0            NaN              1  Documentary,Short
# 1            NaN              5    Animation,Short
# 4            NaN              1       Comedy,Short
# 5            NaN              1              Short
# 6            NaN              1        Short,Sport
# ...          ...            ...                ...
# 10100656     NaN             58             Family
# 10100685     NaN            NaN              Drama
# 10100723     NaN            NaN        Drama,Short
# 10100746     NaN            NaN              Short
# 10100750     NaN            NaN              Short
#
# [1373833 rows x 9 columns]

# %%
# Eliminate movies that are null for runtimeMinutes and for genres
basics = basics.dropna(subset=['runtimeMinutes','genres'], inplace=True)
